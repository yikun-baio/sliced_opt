# %%
import sys
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
import os
import matplotlib.pyplot as plt
import numpy as np
import ot
import time
import numba
import numpy as np
print(os.getcwd())
os.chdir('/home/baly/projects/sliced_opt')
from sopt.library import *
from sopt.lib_ot import *
# Out:
# /home/baly/projects/sliced_opt

# %%
from cvxopt import matrix, solvers

# %%
pi=np.array([[1,2],[3,4]])
pi.reshape(-1)
X=np.random.rand(2)
Y=np.random.rand(3)
M=cost_matrix(X,Y)
mu=np.ones(3)/3
nu=np.ones(2)/2
eps=1

# %%
n,m=M.shape
pi_v=pi.reshape(-1) # this is the 
c=M.reshape(-1) # this is the object function 
margin1=(np.ones((1,1,m))*(np.eye(n).reshape(n,n,1))).reshape(n,n*m)
margin2=(np.eye(m).reshape((m,m,1))*np.ones((1,1,n))).reshape(m,n*m)

A=np.vstack((margin1,margin2))

b=np.concatenate((mu,nu))

A_x=matrix(A)
b_x=matrix(b)
c_x=matrix(c)
sol=solvers.lp(c_x,A_x,b_x)
pi=sol['x']
pi=pi.reshape((n,m))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [58], line 14
#      12 b_x=matrix(b)
#      13 c_x=matrix(c)
# ---> 14 sol=solvers.lp(c_x,A_x,b_x)
#      15 pi=sol['x']
#      16 pi=pi.reshape((n,m))
#
# File ~/miniconda3/envs/pot/lib/python3.10/site-packages/cvxopt/coneprog.py:3009, in lp(c, G, h, A, b, kktsolver, solver, primalstart, dualstart, **kwargs)
#    2999         pslack, dslack = None, None
#    3001     return {'status': status, 'x': x, 's': s, 'y': y, 'z': z,
#    3002         'primal objective': pcost, 'dual objective': dcost,
#    3003         'gap': gap, 'relative gap': relgap,
#    (...)
#    3006         'residual as dual infeasibility certificate': dinfres,
#    3007         'primal slack': pslack, 'dual slack': dslack}
# -> 3009 return conelp(c, G, h, {'l': m, 'q': [], 's': []}, A,  b, primalstart,
#    3010     dualstart, kktsolver = kktsolver, options = options)
#
# File ~/miniconda3/envs/pot/lib/python3.10/site-packages/cvxopt/coneprog.py:573, in conelp(c, G, h, dims, A, b, primalstart, dualstart, kktsolver, xnewcopy, xdot, xaxpy, xscal, ynewcopy, ydot, yaxpy, yscal, **kwargs)
#     571 if kktsolver in defaultsolvers:
#     572     if KKTREG is None and (b.size[0] > c.size[0] or b.size[0] + cdim_pckd < c.size[0]):
# --> 573        raise ValueError("Rank(A) < p or Rank([G; A]) < n")
#     574     if kktsolver == 'ldl':
#     575         factor = misc.kkt_ldl(G, dims, A, kktreg = KKTREG)
#
# ValueError: Rank(A) < p or Rank([G; A]) < n

# %%
b
# Out:
# array([0.33333333, 0.33333333, 0.33333333, 0.5       , 0.5       ])

# %%
n_list=np.arange(10,10000,500)
fig = plt.figure()
ax = plt.subplot(111)

ax.semilogy(n_list,n_list**2,label='$n^2$')
ax.semilogy(n_list,n_list**3,label='$n^3$')
ax.semilogy(n_list,n_list**4,label='$n^4$')
ax.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
c
# Out:
# array([0.05068614, 0.08792492, 0.0028573 , 0.106868  , 0.15863671,
#        0.00233455])
