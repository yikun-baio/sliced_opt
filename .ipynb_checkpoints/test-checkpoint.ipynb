# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
import numba as nb
import os 
import ot
parent_path='/home/baly/projects/sliced_opt'
from scipy.stats import norm
os.chdir(parent_path)
from sopt.library import *
#from sopt.lib_shape import *
from sopt.lib_ot import *   
#from sopt.sliced_opt import *   
from typing import Tuple
import opt1d

# %%
@nb.njit
def test(X,Y):
    return np.dot(X,Y)

@nb.njit(cache=True)
def test2(X,Y):
    n,d=X.shape
    d,m=Y.shape
    M=np.empty((n,m))
    for i in range(n):
        for j in range(m):
            
            M[i,j]=X[i].dot(Y[:,j])
    return M

@nb.njit
def test3(X,Y):
    n,d=X.shape
    d,m=Y.shape
    M=np.empty((n,m))
    for i in nb.prange(n):
        M[i]=X[i].dot(Y)
    return M


Lambda=0.3
X.sort()
Y.sort()


M=cost_matrix(X,Y) 
X=np.random.rand(5000) 
Y=np.random.rand(9000)

# %%
# %%timeit solve_opt(M,Lambda)
# %timeit opt1d.solve(X,Y,Lambda)
# Out:
# 34.3 ms ± 21.3 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# Out:
# 288 µs ± 217 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
@nb.njit(['Tuple((float64,int64[:,:],float64[:,:],float64[:,:]))(float64[:,:],float64[:,:],float64[:])'],parallel=True,fastmath=True)
def sliced_opt_64(X,Y,Lambda_list):
    n,d=X.shape
    n_projections=Lambda_list.shape[0]
    projections=random_projections(d,n_projections,0)
    X_projections=projections.dot(X.T)
    Y_projections=projections.dot(Y.T)
    opt_plan_X_list=np.zeros((n_projections,n),dtype=np.int64)
    #opt_plan_Y_list=np.zeros((n_projections,n),dtype=np.int64)
    opt_cost_list=np.zeros(n_projections)
    for (epoch,(X_theta,Y_theta,Lambda)) in enumerate(zip(X_projections,Y_projections,Lambda_list)):
        X_indice=X_theta.argsort()
        Y_indice=Y_theta.argsort()
        X_s=X_theta[X_indice]
        Y_s=Y_theta[Y_indice]
        M=cost_matrix(X_s,Y_s)
        obj,phi,psi,piRow,piCol=solve_opt(M,Lambda)
        
        L1=recover_indice(X_indice,Y_indice,piRow)
        #L2=recover_indice(Y_indice,X_indice,piCol)
        opt_cost_list[epoch]=obj
        opt_plan_X_list[epoch]=L1
        #opt_plan_Y_list[epoch]=L2
        #sopt_dist=np.sum(opt_cost_list)/n_projections
        sopt_dist=opt_cost_list.sum()/n_projections
    return sopt_dist,opt_plan_X_list,X_projections,Y_projections

def opt_cost_from_plans(X_projections,Y_projections,Lambda_list,opt_plan_X_list):
    n_projections,n=X_projections.shape
    n_projections,m=Y_projections.shape
    opt_cost_list=np.zeros(n_projections)
    for (epoch,(X_theta,Y_theta,Lambda,opt_plan)) in enumerate(zip(X_projections,Y_projections,Lambda_list,opt_plan_list)):
        Domain=opt_plan>=0
        Range=opt_plan[Domain]
        X_select=X_theta[Domain]
        Y_select=Y_theta[Range]
        trans_cost=np.sum(cost_function(X_select,Y_select))
        mass_panalty=Lambda*(m+n-2*Domain.sum())
        opt_cost_list[epoch]=trans_cost+mass_panalty
    return opt_cost_list

# %%
X=np.random.rand(5,3)
Y=np.random.rand(5,3)
Lambda_list=np.full(10,0.1)
opt_cost_list,opt_plan_list,X_projections,Y_projections=opt_plans_64(X,Y,Lambda_list)
opt_cost_list2=opt_cost_from_plans(X_projections,Y_projections,Lambda_list,opt_plan_list)

# %%
opt_cost_list2
# Out:
# array([0.3736714 , 0.08500146, 0.13751569, 0.24060165, 0.12984117,
#        0.37010295, 0.28114216, 0.15423165, 0.344875  , 0.1142665 ])

# %%
opt_cost_list
# Out:
# array([0.3736714 , 0.08500146, 0.13751569, 0.24060165, 0.12984117,
#        0.37010295, 0.28114216, 0.15423165, 0.344875  , 0.1142665 ])

# %%
Y_select
# Out:
# array([[ 0.23120373,  0.23847893,  0.82049336,  0.7051355 ,  0.7021873 ],
#        [-0.38008376, -0.21403227, -0.71315528, -0.0555905 , -0.63946278],
#        [ 0.16287469,  0.52856218,  0.2104359 ,  0.72034766,  0.05371861],
#        [ 0.23120373,  0.23847893,  0.82049336,  0.7051355 ,  0.7021873 ],
#        [-0.6249328 , -0.83877417, -1.09337616, -0.90034135, -0.82996344],
#        [-0.6249328 , -0.83877417, -1.09337616, -0.90034135, -0.82996344],
#        [ 0.16287469,  0.52856218,  0.2104359 ,  0.72034766,  0.05371861],
#        [ 0.23120373,  0.23847893,  0.82049336,  0.7051355 ,  0.7021873 ],
#        [ 0.58181502,  0.63280094,  1.08250938,  0.64134978,  0.87635253],
#        [ 0.58181502,  0.63280094,  1.08250938,  0.64134978,  0.87635253],
#        [-0.38008376, -0.21403227, -0.71315528, -0.0555905 , -0.63946278],
#        [ 0.23120373,  0.23847893,  0.82049336,  0.7051355 ,  0.7021873 ],
#        [ 0.16287469,  0.52856218,  0.2104359 ,  0.72034766,  0.05371861],
# ...

# %%
V=np.power(X_select-Y_select,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [59], line 1
# ----> 1 V=np.power(X_select-Y_select,2)
#
# ValueError: operands could not be broadcast together with shapes (50,) (50,5)

# %%
# Define the curve function
def f(x,a=-4,b=5,base=0.05,h=0.05):
        
    # Define the midpoint of the range
    midpoint = (a + b) / 2
    D=(b-a)/2
    value=h*1/D**2*(D**2-(x-midpoint)**2)+base
    
    return value

# Define the gaussian distributions
mu1, sigma1 = -4, 1
mu2, sigma2 = 5, 0.8
x1 = np.linspace(mu1 - 3*sigma1, mu1 + 3*sigma1, 100)
x2 = np.linspace(mu2 - 3*sigma2, mu2 + 3*sigma2, 100)
y1 = norm.pdf(x1, mu1, sigma1)*0.4
y2 = norm.pdf(x2, mu2, sigma2)*0.4

# Create the figure and axes
fig=plt.figure(figsize=(12,4))
ax = fig.subplots()

# Plot the histograms
ax.fill_between(x1, y1, color='lightcoral', alpha=0.5)
ax.fill_between(x2, y2, color='lightblue', alpha=0.5)


# Plot the points and the connecting curve

x_list = np.linspace(mu1, mu2, 100)
ax.plot(mu1, 0.05, 'ro', markersize=6)
ax.plot(mu2, 0.05, 'bo', markersize=6)
ax.annotate(r'$x$',xy=(0,0), xytext=(mu1-0.6, 0.04), fontsize=16)
ax.annotate(r'$y$',xy=(0,0), xytext=(mu2+0.2, 0.04), fontsize=16)

ax.plot(x_list, f(x_list))


ax.annotate('c(x,y)', xy=(0, 0), xytext=(-0.2, 0.105), fontsize=16)
ax.annotate(r'$\mu$', xy=(0, 0), xytext=(mu1, 0.13), fontsize=16)
ax.annotate(r'$\nu$', xy=(0, 0), xytext=(mu2-0.1, 0.18), fontsize=16)

# Remove the x-axis and y-axis
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
# Set the x-limits and y-limits
ax.set_xlim(-8, 8)
ax.set_ylim(-0, 0.2)

# Show the plot
plt.savefig('ot_problem.pdf',bbox_inches='tight')
plt.show()

# %%
# Define the curve function
def f(x,a=-4,b=5,base=0.05,h=0.05):
        
    # Define the midpoint of the range
    midpoint = (a + b) / 2
    D=(b-a)/2
    value=h*1/D**2*(D**2-(x-midpoint)**2)+base
    
    return value

# Define the gaussian distributions
mu1, sigma1 = -4, 1
mu2, sigma2 = 5, 0.8
x1 = np.linspace(mu1 - 3*sigma1, mu1 + 3*sigma1, 100)
x2 = np.linspace(mu2 - 3*sigma2, mu2 + 3*sigma2, 100)
y1 = norm.pdf(x1, mu1, sigma1)*0.4
y2 = norm.pdf(x2, mu2, sigma2)*0.5

# Create the figure and axes
fig=plt.figure(figsize=(12,4))
ax = fig.subplots()

# Plot the histograms
ax.fill_between(x1, y1, color='lightcoral', alpha=0.5)
ax.fill_between(x1[x1<=mu1-1], y1[x1<=mu1-1], alpha=0.2, color='r')
ax.fill_between(x2, y2, color='lightblue', alpha=0.5)
ax.fill_between(x2[x2>=mu2+1], y2[x2>=mu2+1], alpha=0.2, color='b')


# Plot the points and the connecting curve

x_list = np.linspace(mu1, mu2, 100)
ax.plot(mu1, 0.05, 'ro', markersize=6)
ax.plot(mu2, 0.05, 'bo', markersize=6)
ax.annotate(r'$x$',xy=(0,0), xytext=(mu1-0.35, 0.05), fontsize=14)
ax.annotate(r'$y$',xy=(0,0), xytext=(mu2+0.15, 0.05), fontsize=14)

ax.plot(x_list, f(x_list))


ax.annotate('c(x,y)', xy=(0, 0), xytext=(-0.2, 0.105), fontsize=14)
ax.annotate(r'$\mu$', xy=(0, 0), xytext=(mu1, 0.13), fontsize=14)
ax.annotate(r'$\nu$', xy=(0, 0), xytext=(mu2-0.1, 0.18), fontsize=14)

ax.annotate(r'$\gamma_1$', xy=(0, 0), xytext=(mu1, 0.01), fontsize=14)
ax.annotate(r'$\gamma_2$', xy=(0, 0), xytext=(mu2-0.1, 0.01), fontsize=14)
ax.annotate(r'$\mu-\gamma_1$', xy=(0, 0), xytext=(mu1-2, 0.01), fontsize=14)
ax.annotate(r'$\nu-\gamma_2$', xy=(0, 0), xytext=(mu2+1, 0.01), fontsize=14)

# Remove the x-axis and y-axis
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.set_xticks([])
ax.set_yticks([])
# Set the x-limits and y-limits
ax.set_xlim(-8, 8)
ax.set_ylim(-0, 0.3)

# Show the plot
plt.savefig('opt_problem.pdf',bbox_inches='tight')
plt.show()

# %%
# Define the parameters of the normal distributions
mu1, sigma1 = -2, 1
mu2, sigma2 = 3, 1

# Generate the data for the histograms
x = np.linspace(-6, 6, 1000)
y1 = norm.pdf(x, mu1, sigma1)
y2 = norm.pdf(x, mu2, sigma2)

# Create the figure and axis objects
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the histograms
ax.plot(x, y1, color='r', linestyle='-', label='N(-2,1)')
ax.fill_between(x[x<=mu1], y1[x<=mu1], alpha=0.2, color='r')
ax.plot(x, y2, color='b', linestyle='-', label='N(3,1)')
ax.fill_between(x[x>=mu2], y2[x>=mu2], alpha=0.2, color='b')

# Plot the points and the connecting arc
ax.plot(-2, 0.1, 'ro', markersize=8)
ax.text(-2, 0.1, 'x1', ha='center', va='bottom', fontsize=12)
ax.plot(2, 0.1, 'bo', markersize=8)
ax.text(2, 0.1, 'y1', ha='center', va='bottom', fontsize=12)
arc = plt.get_current_fig_manager().canvas.figure.gca()
arc.annotate("$c(x,y)$", xy=(0.5*(2-(-2)), 0.1+0.01), xytext=(0, 20),
             arrowprops=dict(facecolor='black', arrowstyle="wedge,tail_width=0.7", alpha=0.5),
             ha='center', va='center', fontsize=12)

# Customize the axis and legend
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.legend(loc='upper left')

# Save the figure as a PDF file
plt.savefig('myplot.pdf', bbox_inches='tight')

# %%
f1(x)
# Out:
# array([1.875     , 1.8775    , 1.87999498, 1.88248496, 1.88496993,
#        1.88744989, 1.88992483, 1.89239477, 1.8948597 , 1.89731962,
#        1.89977452, 1.90222442, 1.90466931, 1.90710919, 1.90954405,
#        1.91197391, 1.91439876, 1.9168186 , 1.91923342, 1.92164324,
#        1.92404805, 1.92644784, 1.92884263, 1.93123241, 1.93361718,
#        1.93599693, 1.93837168, 1.94074142, 1.94310614, 1.94546586,
#        1.94782057, 1.95017027, 1.95251495, 1.95485463, 1.9571893 ,
#        1.95951895, 1.9618436 , 1.96416324, 1.96647786, 1.96878748,
#        1.97109209, 1.97339168, 1.97568627, 1.97797585, 1.98026042,
#        1.98253997, 1.98481452, 1.98708406, 1.98934858, 1.9916081 ,
#        1.99386261, 1.9961121 , 1.99835659, 2.00059607, 2.00283053,
#        2.00505999, 2.00728444, 2.00950387, 2.0117183 , 2.01392772,
#        2.01613212, 2.01833152, 2.02052591, 2.02271528, 2.02489965,
#        2.02707901, 2.02925335, 2.03142269, 2.03358702, 2.03574633,
# ...
